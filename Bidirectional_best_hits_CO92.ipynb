# %% [markdown]
# # Generate Bidirectional best hits for two assemblies of the *Yersinia pestis* CO92 genome

# %%
# !ls *CO92*.faa
# Out:
# Y_pestis_CO92.faa      Y_pestis_CO92_2014.faa

# %%
# %%bash
# ORG1=Y_pestis_CO92_2014
# ORG2=Y_pestis_CO92
# for i in `seq 1 4`
# do
#     exonerate   --query $ORG1.faa \
#                 --target $ORG2.faa \
#                 --querychunkid $i \
#                 --querychunktotal 4 \
#                 --bestn 1 \
#                 --ryo "%qi\t%ti\t%ps\n" \
#                 --showvulgar no \
#                 --verbose 0 \
#                 --showalignment no > $ORG1.to.$ORG2.$i.tsv &
# done
# for i in `seq 1 4`
# do
#     exonerate   --target $ORG1.faa \
#                 --query $ORG2.faa \
#                 --querychunkid $i \
#                 --querychunktotal 4 \
#                 --bestn 1 \
#                 --ryo "%qi\t%ti\t%ps\n" \
#                 --showvulgar no \
#                 --verbose 0 \
#                 --showalignment no > $ORG2.to.$ORG1.$i.tsv &
# done

# %% [markdown]
# ##  Concatenate output chunks into one output file for each mapping

# %%
# %%bash
# ORG1=Y_pestis_CO92_2014
# ORG2=Y_pestis_CO92
#
# echo "$ORG1	$ORG2	Similarity_$ORG1.to.$ORG2" > $ORG1.to.$ORG2.tab
# echo "$ORG2	$ORG1	Similarity_$ORG2.to.$ORG1" > $ORG2.to.$ORG1.tab
# for i in `seq 1 4`
# do
#     cat $ORG1.to.$ORG2.$i.tsv >> $ORG1.to.$ORG2.tab
#     cat $ORG2.to.$ORG1.$i.tsv >> $ORG2.to.$ORG1.tab
# done

# %% [markdown]
# ## Read the mappings in to a pandas dataframe

# %%
import pandas as pd
org1 = 'Y_pestis_CO92_2014'
org2 = 'Y_pestis_CO92'
org1_to_org2 = pd.read_table('{}.to.{}.tab'.format(org1, org2))
org2_to_org1 = pd.read_table('{}.to.{}.tab'.format(org2,org1))
display(org1_to_org2.sort_values(by='Similarity_{}.to.{}'.format(org1,org2),ascending=False).head(10))
display(org2_to_org1.sort_values(by='Similarity_{}.to.{}'.format(org2,org1),ascending=False).head(10))
# Out:
#      Y_pestis_CO92_2014                     Y_pestis_CO92  \
# 0            KGA47888.1  gnl|YPES214092|GKDD-2986-MONOMER
# 6402         KGA54032.1  gnl|YPES214092|GKDD-1872-MONOMER
# 6396         KGA54032.1  gnl|YPES214092|GKDD-1982-MONOMER
# 6397         KGA54032.1  gnl|YPES214092|GKDD-4116-MONOMER
# 6398         KGA54032.1  gnl|YPES214092|GKDD-3833-MONOMER
# 6399         KGA54032.1  gnl|YPES214092|GKDD-1032-MONOMER
# 6400         KGA54032.1  gnl|YPES214092|GKDD-2505-MONOMER
# 6401         KGA54032.1  gnl|YPES214092|GKDD-2063-MONOMER
# 6403         KGA54032.1  gnl|YPES214092|GKDD-3034-MONOMER
# 6394         KGA54032.1  gnl|YPES214092|GKDD-2583-MONOMER
#
#       Similarity_Y_pestis_CO92_2014.to.Y_pestis_CO92
# 0                                              100.0
# 6402                                           100.0
# 6396                                           100.0
# 6397                                           100.0
# 6398                                           100.0
# 6399                                           100.0
# 6400                                           100.0
# 6401                                           100.0
# 6403                                           100.0
# 6394                                           100.0
#                          Y_pestis_CO92 Y_pestis_CO92_2014  \
# 0      gnl|YPES214092|GKDD-100-MONOMER         KGA52105.1
# 2966  gnl|YPES214092|GKDD-3058-MONOMER         KGA52519.1
# 2973  gnl|YPES214092|GKDD-3077-MONOMER         KGA51993.1
# 2972  gnl|YPES214092|GKDD-3076-MONOMER         KGA52007.1
# 2971  gnl|YPES214092|GKDD-3075-MONOMER         KGA52005.1
# 2970  gnl|YPES214092|GKDD-3067-MONOMER         KGA52437.1
# 2968  gnl|YPES214092|GKDD-3063-MONOMER         KGA52377.1
# 2967  gnl|YPES214092|GKDD-3059-MONOMER         KGA52433.1
# 2965  gnl|YPES214092|GKDD-3051-MONOMER         KGA52482.1
# 2957  gnl|YPES214092|GKDD-3021-MONOMER         KGA54701.1
#
#       Similarity_Y_pestis_CO92.to.Y_pestis_CO92_2014
# 0                                              100.0
# 2966                                           100.0
# 2973                                           100.0
# 2972                                           100.0
# 2971                                           100.0
# 2970                                           100.0
# 2968                                           100.0
# 2967                                           100.0
# 2965                                           100.0
# 2957                                           100.0

# %% [markdown]
# ## Take the intersection of mappings to get bidirection best hits.

# %%
from IPython.display import display, HTML
org1 = 'Y_pestis_CO92_2014'
org2 = 'Y_pestis_CO92'
bbh  = org1_to_org2.merge(org2_to_org1, 
                 on=[org1, org2], 
                 how='inner',
                 #suffixes=('_albicans2auris','_auris2albicans'),
                 sort=True).sort_values(by='Similarity_{}.to.{}'.format(org1,org2),ascending=False)
display(HTML(bbh.to_html()))
bbh.to_csv('{}_and_{}_BBH.tab'.format(org1,org2), index=False, sep='\t')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Y_pestis_CO92_2014</th>
#       <th>Y_pestis_CO92</th>
#       <th>Similarity_Y_pestis_CO92_2014.to.Y_pestis_CO92</th>
#       <th>Similarity_Y_pestis_CO92.to.Y_pestis_CO92_2014</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>KGA47888.1</td>
#       <td>gnl|YPES214092|GKDD-2986-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2967</th>
#       <td>KGA54241.1</td>
#       <td>gnl|YPES214092|GKDD-2856-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2973</th>
#       <td>KGA54247.1</td>
#       <td>gnl|YPES214092|GKDD-2869-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2972</th>
#       <td>KGA54246.1</td>
#       <td>gnl|YPES214092|GKDD-2916-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2971</th>
#       <td>KGA54245.1</td>
#       <td>gnl|YPES214092|GKDD-2949-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2970</th>
#       <td>KGA54244.1</td>
#       <td>gnl|YPES214092|GKDD-2851-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2969</th>
#       <td>KGA54243.1</td>
#       <td>gnl|YPES214092|GKDD-2880-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2968</th>
#       <td>KGA54242.1</td>
#       <td>gnl|YPES214092|GKDD-2942-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2966</th>
#       <td>KGA54240.1</td>
#       <td>gnl|YPES214092|GKDD-2846-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2924</th>
#       <td>KGA54190.1</td>
#       <td>gnl|YPES214092|GKDD-3405-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2965</th>
#       <td>KGA54239.1</td>
#       <td>gnl|YPES214092|GKDD-2902-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2964</th>
#       <td>KGA54238.1</td>
#       <td>gnl|YPES214092|GKDD-2837-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2963</th>
#       <td>KGA54237.1</td>
#       <td>gnl|YPES214092|GKDD-2863-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2962</th>
#       <td>KGA54236.1</td>
#       <td>gnl|YPES214092|GKDD-2946-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2961</th>
#       <td>KGA54234.1</td>
#       <td>gnl|YPES214092|GKDD-2844-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2960</th>
#       <td>KGA54233.1</td>
#       <td>gnl|YPES214092|GKDD-2925-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2974</th>
#       <td>KGA54248.1</td>
#       <td>gnl|YPES214092|GKDD-2849-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2975</th>
#       <td>KGA54249.1</td>
#       <td>gnl|YPES214092|GKDD-2913-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2976</th>
#       <td>KGA54250.1</td>
#       <td>gnl|YPES214092|GKDD-2952-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2977</th>
#       <td>KGA54251.1</td>
#       <td>gnl|YPES214092|GKDD-2878-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2978</th>
#       <td>KGA54253.1</td>
#       <td>gnl|YPES214092|GKDD-2900-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2979</th>
#       <td>KGA54254.1</td>
#       <td>gnl|YPES214092|GKDD-2859-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2980</th>
#       <td>KGA54255.1</td>
#       <td>gnl|YPES214092|GKDD-2839-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2981</th>
#       <td>KGA54256.1</td>
#       <td>gnl|YPES214092|GKDD-2891-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2982</th>
#       <td>KGA54257.1</td>
#       <td>gnl|YPES214092|GKDD-2835-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2983</th>
#       <td>KGA54260.1</td>
#       <td>gnl|YPES214092|GKDD-2954-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2984</th>
#       <td>KGA54261.1</td>
#       <td>gnl|YPES214092|GKDD-2854-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2985</th>
#       <td>KGA54262.1</td>
#       <td>gnl|YPES214092|GKDD-2941-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2986</th>
#       <td>KGA54263.1</td>
#       <td>gnl|YPES214092|GKDD-2937-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2987</th>
#       <td>KGA54264.1</td>
#       <td>gnl|YPES214092|GKDD-2919-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2988</th>
#       <td>KGA54265.1</td>
#       <td>gnl|YPES214092|GKDD-2864-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2989</th>
#       <td>KGA54266.1</td>
#       <td>gnl|YPES214092|GKDD-2889-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2990</th>
#       <td>KGA54267.1</td>
#       <td>gnl|YPES214092|GKDD-2884-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2959</th>
#       <td>KGA54232.1</td>
#       <td>gnl|YPES214092|GKDD-2933-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2958</th>
#       <td>KGA54231.1</td>
#       <td>gnl|YPES214092|GKDD-2833-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2957</th>
#       <td>KGA54230.1</td>
#       <td>gnl|YPES214092|GKDD-2853-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2940</th>
#       <td>KGA54210.1</td>
#       <td>gnl|YPES214092|GKDD-2581-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2926</th>
#       <td>KGA54192.1</td>
#       <td>gnl|YPES214092|GKDD-2574-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2927</th>
#       <td>KGA54193.1</td>
#       <td>gnl|YPES214092|GKDD-2522-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2928</th>
#       <td>KGA54194.1</td>
#       <td>gnl|YPES214092|GKDD-3396-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2929</th>
#       <td>KGA54195.1</td>
#       <td>gnl|YPES214092|GKDD-2567-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2930</th>
#       <td>KGA54196.1</td>
#       <td>gnl|YPES214092|GKDD-2566-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2931</th>
#       <td>KGA54197.1</td>
#       <td>gnl|YPES214092|GKDD-3373-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2932</th>
#       <td>KGA54199.1</td>
#       <td>gnl|YPES214092|GKDD-3408-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2933</th>
#       <td>KGA54202.1</td>
#       <td>gnl|YPES214092|GKDD-2575-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2934</th>
#       <td>KGA54203.1</td>
#       <td>gnl|YPES214092|GKDD-2552-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2935</th>
#       <td>KGA54204.1</td>
#       <td>gnl|YPES214092|GKDD-2571-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2936</th>
#       <td>KGA54206.1</td>
#       <td>gnl|YPES214092|GKDD-2515-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
#     </tr>
#     <tr>
#       <th>2937</th>
#       <td>KGA54207.1</td>
#       <td>gnl|YPES214092|GKDD-2561-MONOMER</td>
#       <td>100.00</td>
#       <td>100.00</td>
